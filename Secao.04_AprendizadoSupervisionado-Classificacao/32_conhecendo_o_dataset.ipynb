# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus-neres/Machine_Learning_com_Python/blob/main/32_conhecendo_o_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EXPLORAÇÃO, ANÁLISE E TRATAMENTO DOS DADOS: PROJETO PREVISÃO DE DOENÇA CARDÍACA**

# %% [markdown]
# ## **Tratamento e classificação de dados**

# %% [markdown]
# Este projeto tem por objetivo desenvolver um algoritmo de Machine Learning para prever a tendência de uma pessoa desenvolver algum tipo de doença cardíaca com base em alguns fatores clínicos e laboratoriais de referência.

# %% [markdown]
# Os dados foram extraídos do site do Kaggle:
#
# https://www.kaggle.com/fedesoriano/heart-failure-prediction/version/1

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Mateus Neres\OneDrive - Departamento de Ciências Exatas\Machine_Learning_com_Python\Secao.04_AprendizadoSupervisionado-Classificacao\32_conhecendo_o_dataset.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mateus%20Neres/OneDrive%20-%20Departamento%20de%20Ci%C3%AAncias%20Exatas/Machine_Learning_com_Python/Secao.04_AprendizadoSupervisionado-Classificacao/32_conhecendo_o_dataset.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/Mateus%20Neres/OneDrive%20-%20Departamento%20de%20Ci%C3%AAncias%20Exatas/Machine_Learning_com_Python/Secao.04_AprendizadoSupervisionado-Classificacao/32_conhecendo_o_dataset.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
dados = pd.read_csv('/content/drive/MyDrive/curso_Udemy/Machine_Learning_com_Python/heart.csv',
                    sep = ',', encoding = 'iso-8859-1')
# encoding: Codificação de caracteres, geralmente utiliza-se iso-8859-1, utf-8 ou o latin-1

# %% [markdown]
# ## **Explorando dados**

# %%
dados.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
dados.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
dados.shape
# Out:
# (918, 12)

# %% [markdown]
# ## **Análise das variaveis(Atributos)**

# %% [markdown]
# ### **Age = idade**

# %%
dados['Age'].value_counts()
# Out:
# 54    51
# 58    42
# 55    41
# 56    38
# 57    38
# 52    36
# 51    35
# 59    35
# 62    35
# 53    33
# 60    32
# 48    31
# 61    31
# 63    30
# 50    25
# 46    24
# 41    24
# 43    24
# 64    22
# 65    21
# 49    21
# 47    19
# 44    19
# 42    18
# 45    18
# 38    16
# 67    15
# 39    15
# 66    13
# 69    13
# 40    13
# 35    11
# 37    11
# 68    10
# 34     7
# 74     7
# 70     7
# 36     6
# 71     5
# 32     5
# 72     4
# 29     3
# 75     3
# 33     2
# 77     2
# 76     2
# 31     2
# 30     1
# 28     1
# 73     1
# Name: Age, dtype: int64
